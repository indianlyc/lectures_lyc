# %% [markdown]
# # Информатика
#
# ### I четверть
# - 1 неделя	Техника безопасности в компьютерном классе. Повторение пройденного в 9 классе. Диагностический тест	3ч.
# - 2 неделя	Особенности языка Python. Ввод и вывод данных. Операции с целыми и вещественными числами в языке Python	4ч.
# - 3 неделя	Системы счисления. Решение задач. 	4ч.
# - 4 неделя	Свойства основания системы счисления. Решение задач. Условный оператор в языке Питон.	4ч.
# - 5 неделя	Тренировочный тест по теме "Системы счисления". Цикл WHILE в языке Python	4ч.
# - 6 неделя	Контрольный тест по теме "Системы счисления". Цикл FOR в языке Python	4ч.
# - 7 неделя	Логика и компьютер. Логические операции. Таблицы истинности. Строковый тип данных в языке Python	4ч.
# - 8 неделя	Диаграммы Эйлера-Венна. Упрощение логических выражений. Списки в языке Python	4ч.
# - 9 неделя	Синтез логических выражений. Функции в языке Python	4ч.
#
# ### II четверть
# - 10 неделя	Программирование по теме "Битовые операции"	4ч.
# - 11 неделя	Программирование по теме "Системы счисления. Целые числа"	4ч.
# - 12 неделя	Программирование по теме "Системы счисления. Дроби"	4ч.
# - 13 неделя	Проверка числа на простоту. Поиск делителей (программирование)	4ч.
# - 14 неделя	Решето Эратосфена (программирование)	4ч.
# - 15 неделя	Программирование по теме "Множества"	4ч.
#
# ### III четверть
# - 16 неделя	Разбор экзаменационной работы	4ч.
# - 17 неделя	Функции в электронных таблицах. Сортировка и фильтрация данных в MS Excel	4ч.
# - 18 неделя	Анализ истинности логического выражения (отрезки и множества). Словари в языке Python	4ч.
# - 19 неделя	Анализ истинности логического выражения (свойства делимости). Методы словарей	4ч.
# - 20 неделя	Анализ истинности логического выражения (поразрядная конъюнкция). Вложенные словари	4ч.
# - 21 неделя	Анализ истинности логического выражения (неравенства). Модуль random	4ч.
# - 22 неделя	Анализ истинности логического выражения (области на плоскости). Модуль string	4ч.
# - 23 неделя	Общее понятие графа. Простейшие свойства. Линейный поиск в массиве	4ч.
# - 24 неделя	Подсчёт количества путей в графе. Квадратичные сортировки	4ч.
# - 25 неделя	Кратчайший путь в графе. Сортировка подсчётом	4ч.
#
# ### IV четверть
# - 26 неделя	Способы представления графов в компьютере. Матрица смежности	4ч.
# - 27 неделя	Поиск в графе. Волновой алгоритм	4ч.
# - 28 неделя	Вычисление количества информации. Бинарный поиск в массиве	4ч.
# - 29 неделя	Неравномерный двоичный код. Условие Фано. Бинарный поиск по ответу	4ч.
# - 30 неделя	Кодирование, комбинаторика. Вещественный бинарный поиск	4ч.
# - 31 неделя	Кодирование графической и звуковой информации. Сортировка слиянием	4ч.
# - 32 неделя	Решение задач на повторение пройденного в 10 классе	4ч.
# - 33 неделя	Резерв учителя	4ч.

# %% [markdown]
# # Математические основы информатики
#
# ### I четверть
# - 1 неделя	Автоматы: основные понятия. Чтение и построение простейших автоматов	3ч.
# - 2 неделя	Пример нераспознаваемого языка. Пример синхронизируемого автомата. Построение автоматов с заданным условием	3ч.
# - 3 неделя	Контрольная работа по теме "Автоматы". Языки и операции над ними	3ч.
# - 4 неделя	Анализ контрольной работы. Контрольная работа по теме "Языки".	3ч.
# - 5 неделя	Анализ контрольной работы. Машина Тьюринга. Решение задач с листочка	3ч.
# - 6 неделя	Решение задач на эмуляторе «Машина Тьюринга» (первая практика)	3ч.
# - 7 неделя	Решение задач на эмуляторе «Машина Тьюринга» (вторая практика)	3ч.
# - 8 неделя	Контрольная работа по теме "Машина Тьюринга"	3ч.
#
# ### II четверть
# - 9 неделя	Особенности представления чисел в компьютере. Представление целых чисел.	3ч.
# - 10 неделя	Разбор д.з. по теме "Представление целых чисел". Операции с целыми числами	3ч.
# - 11 неделя	Самостоятельная "Целые числа в памяти". Представление вещественных чисел в памяти компьютера	3ч.
# - 12 неделя	Самостоятельная "Операции с целыми числами в памяти". Разбор самостоятельной "Целые числа в памяти" и д.з. по теме "Представление вещественных чисел".	3ч.
# - 13 неделя	Самостоятельная «Представление вещественных чисел». Операции с вещественными числами	3ч.
# - 14 неделя	Самостоятельная «Операции с вещественными числами». Разбор самостоятельной «Представление вещественных чисел» и д.з. по теме «Операции с вещественными числами»	3ч.
#
# ### III четверть
# - 15 неделя	Модели и моделирование. Моделирование биоритмов	3ч.
# - 16 неделя	Математические модели. Модель неограниченного роста. Модель ограниченного роста	3ч.
# - 17 неделя	Моделирование полета тела	3ч.
# - 18 неделя	Моделирование эпидемии	3ч.
# - 19 неделя	Метод Монте-Карло	3ч.
# - 20 неделя	Моделирование работы магазина	3ч.
# - 21 неделя	IP-адресация	3ч.
# - 22 неделя	Программа "Лампанель". Арифметические операции	3ч.
# - 23 неделя	Программа "Лампанель". Процессор и устройства вывода	3ч.
# - 24 неделя	Программа "Лампанель". Работа со стеком	3ч.
#
# ### IV четверть
# - 25 неделя	Способы представления графов в компьютере. Список ребер	3ч.
# - 26 неделя	Поиск в графе. Поиск в глубину	3ч.
# - 27 неделя	Применения алгоритма поиска в глубину	3ч.
# - 28 неделя	Поиск в графе. Поиск в ширину	3ч.
# - 29 неделя	Поиск в ширину для неединичных ребер	3ч.
# - 30 неделя	Алгоритм Дейкстры	3ч.
# - 31 неделя	Реализация алгоритма Дейкстры для больших разреженных графов	3ч.
# - 32 неделя	Резерв учителя	3ч.
