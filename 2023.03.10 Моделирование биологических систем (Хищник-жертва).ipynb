# %% [markdown]
# Поляков Еремин 11 кл 1 часть 98стр
# 1)main1.py
# 1. Создать поле с едой (пусть клетка будет размером 10 на 10) а поле размером 800 на 800
# 2. Создать 1 шушунчика-приведение который случайно перемещаются таким образом что с вероятность 50% он оставляет прежнее направление движения, а с вероятностью 50% двигается в оставшиеся три стороны. Рождается шушунчик уже с каким-то случайным направлением движения. Если шушунчик съедает 3 еды то почкуется.
# 3. Если шушунчик не встречает еду за 50 циклов он умирает.
# 4. Еда через 3 цикла восстанавливается на тех местах где съедена
# (один цикл одно перещение каждого персоонажа, кроме еды)
# 5. построить графики и сохранить их как изображение количества шушников от времени (циклов)
# 6. построить на этих же графиках модели ограниченного и не ограниченного роста с подобром параметров так чтобы графики были максимально похожи (mean(y-y1) -> min)
#
# границы поля замкнуты друг на друга если ушел вправо появляшься слева и наоборот. аналогично с верхом и низом (остаток от деления поможет)
#
# 2)main2.py
# 1. Создать поле с едой (пусть клетка будет размером 10 на 10) а поле размером 800 на 800
# 2. Создать 1 шушунчика-приведение который случайно перемещаются таким образом что с вероятность 50% он оставляет прежнее направление движения, а с вероятностью 50% двигается в оставшиеся три стороны. Рождается шушунчик уже с каким-то случайным направлением движения. Если шушунчик съедает 3 еды то почкуется.
# 3. Если шушунчик не встречает еду за 50 циклов он умирает.
# 4. Еда через 50 цикла восстанавливается на тех местах где съедена
# (один цикл одно перещение каждого персоонажа, кроме еды)
# 5. построить графики и сохранить их как изображение количества шушников от времени (циклов)
# 6. построить на этих же графиках модели ограниченного и не ограниченного роста с подобром параметров так чтобы графики были максимально похожи (mean(y-y1) -> min)
#
# 3)main3.py
# 1. Создать поле с едой (пусть клетка будет размером 10 на 10) а поле размером 800 на 800
# 2. Создать 1 шушунчика-приведение который случайно перемещаются таким образом что с вероятность 50% он оставляет прежнее направление движения, а с вероятностью 50% двигается в оставшиеся три стороны. Рождается шушунчик уже с каким-то случайным направлением движения. Если шушунчик съедает 3 еды то почкуется.
# 3. Если шушунчик не встречает еду за 50 циклов он умирает.
# 4. Создать чебуратора, который при встрече съедает шушунчика и размножается. Но если не встретит шушунчика в течении 50 циклов умирает.
# 5. Еда через 3 цикла восстанавливается на тех местах где съедена
# (один цикл одно перещение каждого персоонажа, кроме еды)
# 6. построить графики и сохранить их как изображение количества шушников от времени (циклов)
# 7. построить на этих же графиках модели хищник-жертва с подбором параметров так чтобы графики были максимально похожи (mean(y-y1) -> min)
