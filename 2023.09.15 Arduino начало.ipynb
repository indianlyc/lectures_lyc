# %% [markdown]
# С помощью одной ардуино, двух резисторов, двух светодиодов, двух потенциометров, двух сервомоторов, создать схему, которая позволяет с помощью одного из потенциомера регулировать напор воды (в качестве насосов выступают светодиоды, в качестве кранов - сервоприводы после насоса), а второго регулировать теплоту воды - степень открытия холодного и горячего крана.
#
# два трубы одна холодная другая горячая на них стоят насосы после насосов стоят краны потом они объединяются в одну трубу
#
# один потенциометр регулирует напор, второй теплоту воды. при регулировки теплоты напор не должен меняться, при регулировке напора теплота не должа меняться
#
# отправлять как dz230915/main.brd

# %% [markdown]
# Сделать поливку цветов. С помощью сервоматора включаем воду, диодом показываем что идет полив, с помощью датчика влажности контролируем чтобы влажность почвы сохранялась в пределах заданных (константами вначале исходного файла) величин. Если влажность почвы ниже уровня - поливаем пока не стала серединой между границами, после этого выключаем полив. Если влажность почвы выше уровня включаем лампу пока не стало в середину между границами.
#
# отправлять как dz230915/poliv.brd
